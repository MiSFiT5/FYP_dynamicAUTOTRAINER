# %% [markdown]
# packages

# %%
import pandas as pd
import numpy as np

# %%
tableTest = pd.read_csv(r"C:\Users\Administrator\Desktop\AUTOTRAINER\case_1_later=20_%s.csv")
tableTest
# Out:
#     Unnamed: 0      loss  accuracy  val_loss  val_accuracy
# 0            0  0.903383  0.661217  0.414222        0.8498
# 1            1  0.407028  0.892350  0.254127        0.9350
# 2            2  0.285661  0.926033  0.325522        0.9182
# 3            3  0.412570  0.881017  0.346364        0.9032
# 4            4  0.291593  0.923067  0.321549        0.9116
# 5            5  0.329361  0.912117  0.742271        0.7486
# 6            6  0.305659  0.920817  0.227168        0.9460
# 7            7  0.230461  0.942867  0.490280        0.8712
# 8            8  0.323737  0.912767  0.346529        0.8999
# 9            9  0.338283  0.898350  0.476793        0.8582
# 10          10  0.444655  0.863817  0.316806        0.9179
# 11          11  0.246410  0.935483  0.225151        0.9432
# 12          12  0.252664  0.931850  0.249789        0.9371
# 13          13  0.276537  0.922133  0.451704        0.8425
# 14          14  0.469880  0.850883  0.333986        0.9079
# 15          15  0.445640  0.870317  0.632046        0.8143
# 16          16  0.454038  0.866050  0.653325        0.7713
# 17          17  0.397046  0.886833  0.278287        0.9366
# 18          18  0.248578  0.941567  0.232450        0.9418
# 19          19  0.231743  0.946617  0.202447        0.9547
# 20          20  0.414510  0.879183  0.485234        0.8548
# 21          21  0.399995  0.894483  0.346889        0.9203
# 22          22  0.469191  0.860183  0.594551        0.8115
# 23          23  0.456664  0.882417  0.449213        0.9184
# 24          24  0.454890  0.886700  0.413829        0.9192
# 25          25  0.326705  0.926667  0.321699        0.9342
# 26          26  0.307499  0.931483  0.354655        0.9328
# 27          27  0.350474  0.924050  0.329606        0.9322
# 28          28  0.365231  0.922550  0.424330        0.8823
# 29          29  0.496761  0.869633  0.489010        0.8925
# 30          30  0.482116  0.884300  0.452783        0.9104
# 31          31  0.550908  0.856200  0.519552        0.8880
# 32          32  0.662938  0.805733  0.783799        0.7862
# 33          33  0.571365  0.849400  0.469384        0.9104
# 34          34  0.513628  0.875550  0.594139        0.8224
# 35          35  0.548341  0.862817  0.688964        0.8090
# 36          36  0.661635  0.813533  0.596559        0.8828
# 37          37  0.543968  0.878450  0.531773        0.9180
# 38          38  0.437400  0.916717  0.494683        0.9032
# 39          39  0.337529  0.935533  0.383433        0.9434
# 40          40  0.340078  0.931983  0.497761        0.9282
# 41          41  0.447078  0.890450  0.665217        0.8217
# 42          42  0.563199  0.843067  0.491996        0.9199
# 43          43  0.747362  0.774450  0.641346        0.8346
# 44          44  0.842938  0.740100  0.885591        0.7638
# 45          45  0.944088  0.709300  0.776246        0.7696
# 46          46  0.698915  0.796400  0.662201        0.8503
# 47          47  0.848676  0.732450  0.758783        0.8226
# 48          48  0.778480  0.763400  0.666150        0.8112
# 49          49  0.623508  0.819533  0.671918        0.8076

# %%
loss = tableTest['loss']
acc = tableTest['accuracy']
val_loss = tableTest['val_loss']
val_acc = tableTest['val_accuracy']

# %%
# unstable_threshold=0.05
# unstable_rate=0.25

# %%
def ol_judge(acc,threshold,rate):
    
    maximum=[]
    minimum=[]
    count=0
    
    for i in range(len(acc)):
        if i==0 or i ==len(acc)-1:
            continue
        if acc[i]-acc[i-1]>=0 and acc[i]-acc[i+1]>=0:
            maximum.append(acc[i])
        if acc[i]-acc[i-1]<=0 and acc[i]-acc[i+1]<=0:
            minimum.append(acc[i])
    for i in range(min(len(maximum),len(minimum))):
        if maximum[i]-minimum[i]>=threshold:
            count+=1
    if count>=rate*len(acc):
        return True
    else:
        return False

# %%
# unstable_threshold=0.05
# unstable_rate=0.25
print(ol_judge(val_acc, 0.05, 0.25))
# Out:
# False
