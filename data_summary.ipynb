# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import title

# %%
labels = 'Bug detected', 'No bug detected'  # 定义标签
sizes = [69, 31 ]  # 每一块的比例
colors = [ 'gold', 'lightskyblue']  # 每一块的颜色
explode = (0.1, 0)  # 突出显示，这里仅仅突出显示第二块（即'Hogs'）

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
mytitle = "case_100epoch_1"
plt.title(mytitle)
plt.axis('equal')  # 显示为圆（避免比例压缩为椭圆）
plt.show()

# %%
plt.savefig("test.png", dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [32, 24, 31, 31, 35, 28, 32, 29, 28, 28, 28, 27, 34, 27, 28, 33, 33, 30, 28, 28, 25, 25, 29, 31, 27, 27, 26, 27, 28, 30, 28, 29, 30, 27, 29, 29, 29, 26, 29, 30, 26, 25, 30, 25, 27, 30, 28, 32, 34, 28, 31, 30, 31, 30, 30, 27, 28, 29, 30, 27, 31, 31, 31, 31, 27, 30, 29]

# Compute the histogram with 10 bins
n, bins, patches = plt.hist(data, bins=10)

plt.xlabel('Epoch')
plt.ylabel('Frequency')
plt.title('case_100epoch_2')

plt.show()

# %%
labels = 'Bug detected', 'No bug detected'  # 定义标签
sizes = [64, 36]  # 每一块的比例
colors = [ 'gold', 'lightskyblue']  # 每一块的颜色
explode = (0.1, 0)  # 突出显示，这里仅仅突出显示第二块（即'Hogs'）

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
mytitle = "case_50epoch_2_CPUversion"
plt.title(mytitle)
plt.axis('equal')  # 显示为圆（避免比例压缩为椭圆）
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [12, 14, 17, 12, 14, 13, 18, 13, 13, 12, 15, 15, 14, 15, 14, 13, 16, 14, 14, 14, 15, 13, 14, 12, 14, 16, 16, 14, 16, 13, 15, 13, 14, 15, 14, 14, 13, 10, 14, 15, 13, 16, 14, 13, 15, 13, 14, 12, 15, 15, 14, 14, 13, 14, 12, 13, 14, 15, 14, 14, 16, 13, 16, 13]
# Compute the histogram with 10 bins
n, bins, patches = plt.hist(data, bins=8,range=(0,50))

plt.xlabel('Epoch')
plt.ylabel('Frequency')
plt.title('case_50epoch_CPU')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [52, 35, 35, 33, 35, 39, 35, 36, 37, 36, 33, 45, 48, 41, 48, 36, 36, 36, 39, 36, 33, 34, 41, 37, 38, 37, 38, 36, 36, 35, 35, 38, 36, 40, 42]
# Compute the histogram with 10 bins
plt.hist(data, bins=10, range=(30, 55))

plt.xlabel('Epoch')
plt.ylabel('Frequency')
plt.title('case_125epoch_1')

plt.show()

# %%
labels = 'Bug detected 24', 'No bug detected 26'  # 定义标签
sizes = [24, 26]  # 每一块的比例
colors = [ 'gold', 'lightskyblue']  # 每一块的颜色
explode = (0.1, 0)  # 突出显示，这里仅仅突出显示第二块（即'Hogs'）

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
mytitle = "case_125epoch_2"
plt.title(mytitle)
plt.axis('equal')  # 显示为圆（避免比例压缩为椭圆）
plt.show()

# %% [markdown]
# CPU：[12, 14, 17, 12, 14, 13, 18, 13, 13, 12, 15, 15, 14, 15, 14, 13, 16, 14, 14, 14, 15, 13, 14, 12, 14, 16, 16, 14, 16, 13, 15, 13, 14, 15, 14, 14, 13, 10, 14, 15, 13, 16, 14, 13, 15, 13, 14, 12, 15, 15, 14, 14, 13, 14, 12, 13, 14, 15, 14, 14, 16, 13, 16, 13]
# 这组数据代表总共一百轮训练，每轮训练50次迭代，数组中的数据表示bug出现时的迭代数
# CASE_1: [14, 14, 12, 15, 16, 14, 18, 12, 10, 14, 13, 15, 14, 15, 15, 12, 13, 13, 12, 15, 16, 12, 14, 14, 15, 15, 14, 11, 18, 12, 17, 14, 11, 13, 12, 15, 15, 13, 13, 15, 16, 12, 14, 13, 14, 15, 15, 11, 15, 14, 16, 15, 15, 15, 16, 15, 14, 12, 12, 12]
# 这组数据代表总共一百轮训练，每轮训练50次迭代，数组中的数据表示bug出现时的迭代数，只不过该组数据应用到了GPU
# CASE_anotherModel: [16, 12, 12, 15, 13, 12, 13, 12, 17, 14, 13, 12, 14, 12, 14, 13, 12, 11, 15, 17, 16, 13, 12, 14, 13, 15, 15, 17, 13, 10, 12, 13, 13, 12, 15]
# 这组数据代表总共一百轮训练，每轮训练50次迭代，数组中的数据表示bug出现时的迭代数，不过该组数据用了另一个相对不易产生bug的模型，数据量相对少
# case_100epoch_1: [32, 32, 25, 29, 28, 28, 31, 27, 28, 30, 28, 31, 32, 32, 27, 31, 32, 27, 30, 27, 28, 28, 27, 33, 31, 29, 30, 35, 27, 27, 27, 28, 31, 33, 31, 27, 31, 35, 28, 27, 25, 28, 33, 30, 31, 34, 30, 30, 31, 29, 25, 29, 32, 26, 29, 26, 27, 28, 29, 36, 29, 32, 29, 30, 33, 26, 30, 28, 28]
# 这组数据代表总共一百轮训练，每轮训练100次迭代，数组中的数据表示bug出现时的迭代数
# case_100epoch_2: [32, 24, 31, 31, 35, 28, 32, 29, 28, 28, 28, 27, 34, 27, 28, 33, 33, 30, 28, 28, 25, 25, 29, 31, 27, 27, 26, 27, 28, 30, 28, 29, 30, 27, 29, 29, 29, 26, 29, 30, 26, 25, 30, 25, 27, 30, 28, 32, 34, 28, 31, 30, 31, 30, 30, 27, 28, 29, 30, 27, 31, 31, 31, 31, 27, 30, 29]
# 这组数据代表另外的一百轮训练，每轮训练100次迭代，数组中的数据表示bug出现时的迭代数
# Case_125epoch_1: [52, 35, 35, 33, 35, 39, 35, 36, 37, 36, 33, 45, 48, 41, 48, 36, 36, 36, 39, 36, 33, 34, 41, 37, 38, 37, 38, 36, 36, 35, 35, 38, 36, 40, 42]
# 这组数据代表总共五十轮训练，每轮训练125次迭代，数组中的数据表示bug出现时的迭代数
# Case_125epcoh_2: [35, 37, 35, 32, 53, 41, 35, 36, 35, 39, 40, 34, 34, 37, 34, 37, 38, 39, 38, 41, 43, 40, 34, 47]
# 这组数据代表另外五十轮训练，每轮训练125次迭代，数组中的数据表示bug出现时的迭代数

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [47, 48, 51, 47, 52, 47, 44, 47, 55, 40, 47, 49, 42, 49, 44, 45, 39]
# Compute the histogram with 10 bins
plt.hist(data, bins=100, range=(0, 150))

plt.xlabel('Epoch')
plt.ylabel('Frequency')
plt.title('case_150epoch_1')

plt.show()

# %%
labels = 'Bug detected 19', 'No bug detected 31'  # 定义标签
sizes = [19, 31]  # 每一块的比例
colors = [ 'gold', 'lightskyblue']  # 每一块的颜色
explode = (0.1, 0)  # 突出显示，这里仅仅突出显示第二块（即'Hogs'）

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
mytitle = "case_150epoch_1"
plt.title(mytitle)
plt.axis('equal')  # 显示为圆（避免比例压缩为椭圆）
plt.show()
